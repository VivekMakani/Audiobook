# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-rog/Audiobook/blob/main/AudioBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# !pip install gtts

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6832ff6-95f3-479a-8335-2289d2bc28b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6832ff6-95f3-479a-8335-2289d2bc28b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

book = open('Vivek_intro.pdf', 'rb')
pdfReader = PyPDF2.PdfReader(book)
pages = len(pdfReader.pages)

# text = "I will speak this text"
# tts = gTTS(text)
# tts.save('speech.mp3')
# Audio('speech.mp3', autoplay=True)

for num in range(0,pages):
    page = pdfReader.pages[num]
    text = page.extract_text()
    tts = gTTS(text)

tts.save('speech.mp3')
Audio('speech.mp3', autoplay=True)
# Out:
# ...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# creating audiobook using in-built python libraries
# import pyttsx3
# import PyPDF2
# book = open('Vivek_intro.pdf', 'rb')
# pdfReader = PyPDF2.PdfReader(book)
# pages = len(pdfReader.pages)

# print(pages)

# speaker = pyttsx3.init()
# for num in range(0,pages):
#     page = pdfReader.pages[num]
#     text = page.extract_text()
#     speaker.say(text)
#     speaker.runAndWait()

# %%
# !pip install pyttsx3==2.71
# import pyttsx3
# engine = pyttsx3.init()
# engine.say("I will speak this text")
# engine.runAndWait()
